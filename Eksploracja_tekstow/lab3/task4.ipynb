# %% [markdown]
# **Zadanie 4. (6p)** Napisz program, korygujący błędy, który czyta ze standardowego wejścia plik
# zawierający wiersze, w których mamy pary: (słowo-poprawne, słowo-wpisane). Przeczytawszy parę,
# dokonuje korekty i sprawdza, czy jest taka jak trzeba. Wypisuje błędy i podlicza na koniec ich
# procentowy udział we wszystkich korektach. Oczywiście korzysta z informacji o poprawnym słowie
# **tylko** do sprawdzenia, czy popełnił błąd. Dla zbioru testowego 1 powinien mieć skuteczność ponad
# 70%. Wymagana skuteczność dla zbioru testowego 2 zostanie podana później.
#
# Uwaga: nie wolno spamiętywać żadnych danych z poprzednich korekt (dane są tak skontruowane,
# że taka strategia dawałaby „nieuczciwą” przewagę programowi z niej korzystającemu). Uwaga: na
# przyszłych zajęciach zrobimy osobno punktowany konkurs poprawiania literówek.

# %%
import csv
import string
import logging
from heapq import heappush, heappop

# %%
logging.basicConfig(level=logging.INFO)

# %%
TEST_DATASET_FILE_PATH = 'data/literowki1.txt'
BASE_FORMS_FILE_PATH = 'data/polimorfologik-2.1.txt'

# %%
with open(BASE_FORMS_FILE_PATH) as f:
    _ALL_WORDS = {word for _base, word, *_ in csv.reader(f, delimiter=';')}
    
def is_correct(word):
    return word in _ALL_WORDS

# %%
POLISH_CHARACTERS = 'ąćęłńóśżź'
ASCII_BY_POLISH = {pol: asc for pol, asc in zip(POLISH_CHARACTERS, 'acelnoszz')}
ALL_CHARACTERS = string.ascii_lowercase + POLISH_CHARACTERS

# %%
def all_deletions(word):
    for i in range(len(word)):
        yield f'{word[:i]}{word[i + 1 :]}'

def all_insertions(word):
    for i in range(len(word)):
        for char in ALL_CHARACTERS:
            yield f'{word[:i]}{char}{word[i:]}'

def all_substitutions(word):
    for i in range(len(word)):
        for char in ALL_CHARACTERS:
            yield f'{word[:i]}{char}{word[i + 1 :]}'

def all_polish_substitutions(word):
    """Polish to ASCII and vice versa"""
    for i, orig in enumerate(word):
        char = None
        if pol := ASCII_BY_POLISH.get(orig):
            char = pol
        else:
            for k, v in ASCII_BY_POLISH.items():
                if v == orig:
                    char = k
        if char:
            yield f'{word[:i]}{char}{word[i + 1 :]}'
            
def all_ascii_substitutions(word):
    for i in range(len(word)):
        for char in string.ascii_lowercase:
            yield f'{word[:i]}{char}{word[i + 1 :]}'

def all_swaps(word):
    for i in range(len(word) - 1):
        for j in range(i + 1, len(word)):
            yield f'{word[:i]}{word[j]}{word[i + 1:j]}{word[i]}{word[j + 1 :]}'

EDITS_COSTS = {
    all_deletions: 2,
    all_insertions: 2,
    #all_substitutions: 1,
    all_polish_substitutions: 1,
    all_ascii_substitutions: 2,
    all_swaps: 1,
}            

def all_edits(word):
    """Yields words within one edit operation of the given `word`
    and their respective costs.
    """
    for gen, cost in EDITS_COSTS.items():
        for edit in gen(word):
            yield cost, edit

# %%
def stream_edits(word, max_cost=3):
    q = []
    cost = 0
    heappush(q, (cost, word))
    while cost < max_cost:
        cost, word = heappop(q)
        for additional_cost, edit in all_edits(word):
            yield edit
            heappush(q, (cost + additional_cost, edit))

# %%
def is_likely(word, edit):
    return is_correct(edit) and word[0] == edit[0] and word[-1] == edit[-1]

# %%
def correct(word):
    for edit in stream_edits(word):
        if is_likely(word, edit):
            return edit

# %%
with open(TEST_DATASET_FILE_PATH) as f:
    num_samples = 0
    correct_results = 0
    for line in f:
        num_samples += 1
        expected, word = line.split()
        actual = correct(word)
        if expected == actual:
            correct_results += 1
        logging.info('%s %s %s', word, expected, actual)
    print(correct_results / num_samples)
# Out:
# INFO:root:lokomowtuwa lokomotywa lokomotywa
# INFO:root:kolokotywa lokomotywa kolorytowa
# INFO:root:lokonowaywa lokomotywa None
# INFO:root:kolomotywa lokomotywa kolorytowa
# INFO:root:lokotaywa lokomotywa None
# INFO:root:prawodpodoniestso prawdopodobieństwo None
# INFO:root:prawdopopdobieństwo prawdopodobieństwo prawdopodobieństwo
# INFO:root:prawdopodobieńśtwo prawdopodobieństwo prawdopodobieństwo
# INFO:root:prawodpodoniesnitswo prawdopodobieństwo None
# INFO:root:prawwdopodobeinistwo prawdopodobieństwo None
# INFO:root:prawdopodobiensitwao prawdopodobieństwo None
# INFO:root:prawdopodonbieńśtwo prawdopodobieństwo prawdopodobieństwo
# INFO:root:prawdopdoodobienśtwo prawdopodobieństwo None
# INFO:root:prawdopodbieństwi prawdopodobieństwo None
# INFO:root:prawodpoodbieństwo prawdopodobieństwo prawdopodobieństwo
# INFO:root:prawdomównu prawdomówny prawdomównemu
# INFO:root:proawdomówny prawdomówny prawdomówny
# INFO:root:prawdowny prawdomówny prawdzony
# INFO:root:kompteurerk komputerek komputerek
# INFO:root:komputerer komputerek komputer
# INFO:root:komputerek komputerek komputerek
# INFO:root:koreiterek komputerek korektorek
# INFO:root:kompetuerek komputerek komputerek
# INFO:root:dziewczysna dziewczyna dziewczyna
# INFO:root:dziewnczyna dziewczyna dziewczyna
# INFO:root:wdziewczynaa dziewczyna None
# INFO:root:dziewczynaa dziewczyna dziewczyna
# INFO:root:dziewnczyna dziewczyna dziewczyna
# INFO:root:dziewczyna dziewczyna dziewczynia
# INFO:root:dzieczyna dziewczyna dziewczyna
# INFO:root:dziewcyzan dziewczyna dziewczyn
# INFO:root:dziewczyan dziewczyna dziewczyn
# INFO:root:przyjażć przyjaźń przyjąć
# INFO:root:przyjazn przyjaźń przygan
# INFO:root:przyjaźć przyjaźń przyjąć
# INFO:root:przyajźń przyjaźń przyjaźń
# INFO:root:przyjażćń przyjaźń przyjaźń
# INFO:root:niszcyciek niszczyciel None
# INFO:root:niszcyzciel niszczyciel niszczyciel
# INFO:root:niszcycie niszczyciel niszczycie
# INFO:root:niszcyciek niszczyciel None
# INFO:root:niwzyczyciel niszczyciel niszczyciel
# INFO:root:niewszczcyciel niszczyciel None
# INFO:root:paniernik pancernik papiernik
# INFO:root:paniernik pancernik papiernik
# INFO:root:oancernik pancernik ornecianek
# INFO:root:panceerrnik pancernik pancernik
# INFO:root:nauczenycielak nauczycielka None
# INFO:root:nayczucielka nauczycielka nauczycielka
# INFO:root:nayczyciela nauczycielka nauczyciela
# INFO:root:nauczycielak nauczycielka nauczycielek
# INFO:root:nayczycielka nauczycielka nauczycielka
# INFO:root:ślinainka ślinianka ślinianka
# INFO:root:ślinainka ślinianka ślinianka
# INFO:root:slinianka ślinianka sejnianka
# INFO:root:ślinianak ślinianka ślinianek
# INFO:root:ślinianaj ślinianka ślinionej
# INFO:root:oustenia pustelnia obstania
# INFO:root:pustalnia pustelnia pustelnia
# INFO:root:pustelania pustelnia pustelnia
# INFO:root:drożdżówe drożdżowe drożdżówce
# INFO:root:drożdizowe drożdżowe None
# INFO:root:drrożdżówe drożdżowe drożdżowe
# INFO:root:drozdzowe drożdżowe drozdowe
# INFO:root:drozsdowe drożdżowe drozdowe
# INFO:root:szakfak szafka szablak
# INFO:root:szakfa szafka szafa
# INFO:root:szafka szafka szaka
# INFO:root:szafkaaa szafka szafarka
# INFO:root:szaadka szafka szaradka
# INFO:root:lazienak łazienka None
# INFO:root:łązienka łazienka łazienka
# INFO:root:laizenka łazienka lirenka
# INFO:root:łąązienka łazienka łazienka
# INFO:root:łązeinka łazienka łazienka
# INFO:root:azienka łazienka akineza
# INFO:root:łazienka łazienka łazienka
# INFO:root:łąxienka łazienka łazienka
# INFO:root:paneterea pantera pantera
# INFO:root:panetra pantera paletra
# INFO:root:panterea pantera pantera
# INFO:root:panetera pantera pantera
# INFO:root:pańtera pantera patera
# INFO:root:pantereea pantera pantera
# INFO:root:patnera pantera patera
# INFO:root:beswtuwdnica bezwstydnica None
# INFO:root:beswsytydnica bezwstydnica bezwstydnica
# INFO:root:bezwstydbica bezwstydnica bezwstydnica
# INFO:root:bezwstydinca bezwstydnica bezwstydnica
# INFO:root:beztwydnica bezwstydnica bezwstydnica
# INFO:root:plenrarnej plenarnej plenarnej
# INFO:root:plenarnej plenarnej plenarnej
# INFO:root:plenarneh plenarnej plenarnych
# INFO:root:złotowuysty złotousty złotousty
# INFO:root:złotousty złotousty złotousty
# INFO:root:zlootusty złotousty złotousty
# INFO:root:zlotousty złotousty złotousty
# INFO:root:złótoósty złotousty złotousty
# INFO:root:kalamiarnica kałamarnica kałamarnica
# INFO:root:kałąmarnirca kałamarnica kałamarnica
# INFO:root:kałamiaranica kałamarnica kałamarnica
# INFO:root:kaładarnica kałamarnica kałamarnica
# INFO:root:kaładmanica kałamarnica kałamarnica
# INFO:root:kaładmrnica kałamarnica kałamarnica
# INFO:root:kalamanriaca kałamarnica kałamarnica
# INFO:root:kałamsianica kałamarnica None
# INFO:root:kałąmiarnica kałamarnica kałamarnica
# INFO:root:kałarnica kałamarnica kafarnika
# INFO:root:kałaamica kałamarnica None
# INFO:root:ekeierak ekierka ekierek
# INFO:root:ekeirka ekierka ekierka
# INFO:root:ekairka ekierka ekierka
# INFO:root:ekirerka ekierka ekierka
# INFO:root:ekrrierka ekierka ekierka
# INFO:root:ekierka ekierka ekierka
# INFO:root:keierka ekierka kierka
# INFO:root:ekerka ekierka ekierka
# INFO:root:ekirrka ekierka ekierka
# INFO:root:wypaczkowal wypączkował None
# INFO:root:wypąćczkował wypączkował wypączkował
# INFO:root:wypączkaował wypączkował wypączkował
# INFO:root:wypaczkowa wypączkował wypadkowa
# INFO:root:wypwczkowal wypączkował None
# INFO:root:górzystys górzysty None
# INFO:root:górzystay górzysty górzysty
# INFO:root:rógrzysy górzysty None
# INFO:root:górazysty górzysty górzysty
# INFO:root:gorzystya górzysty górzysta
# INFO:root:forzysty górzysty faszysty
# INFO:root:gurzysty górzysty górzysty
# INFO:root:pelnaimocnik pełnomocnik None
# INFO:root:pelnonicnik pełnomocnik None
# INFO:root:pełńonocnik pełnomocnik pełnomocnik
# INFO:root:epłnonockin pełnomocnik None
# INFO:root:pełnonocini pełnomocnik pełnomocni
# INFO:root:pełnomocnik pełnomocnik pełnomocnik
# INFO:root:pełnonicnik pełnomocnik pełnomocnik
# INFO:root:pełnomoncik pełnomocnik pełnomocnik
# INFO:root:pełnomocnik pełnomocnik pełnomocnik
# INFO:root:pelnomincik pełnomocnik pełnomocnik
# INFO:root:pelnomicnik pełnomocnik pełnomocnik
# INFO:root:pelnomicnik pełnomocnik pełnomocnik
# INFO:root:pelnomicnik pełnomocnik pełnomocnik
# INFO:root:górnica górnicza górnicka
# INFO:root:górnicza górnicza górnica
# INFO:root:gornicza górnicza górnicza
# INFO:root:gornucza górnicza górnicza
# INFO:root:gurnicza górnicza górnicza
# INFO:root:zabijczego zabójczego zabijanego
# INFO:root:zabójaczefo zabójczego zabójczego
# INFO:root:zabujczeog zabójczego None
# INFO:root:zabujczefo zabójczego None
# INFO:root:zabojczego zabójczego zabójczego
# INFO:root:zabojczeoh zabójczego None
# INFO:root:czabojjczego zabójczego None
# INFO:root:norosorzec nosorożec None
# INFO:root:nosoroczec nosorożec None
# INFO:root:nosorożęc nosorożec nosorożec
# INFO:root:nosoorwec nosorożec None
# INFO:root:nosocrożęc nosorożec nosorożec
# INFO:root:nosorozsezc nosorożec None
# INFO:root:nosorwożęć nosorożec None
# INFO:root:nosoronec nosorożec nosorożec
# INFO:root:słóńątko słoniątko słoniątko
# INFO:root:słoniatkao słoniątko słoniątko
# INFO:root:słoniarko słoniątko słoniątko
# INFO:root:słoniątko słoniątko słoniątko
# INFO:root:slonatko słoniątko sonatko
# INFO:root:słoniatko słoniątko słoniątko
# INFO:root:sloniątkoo słoniątko słoniątko
# INFO:root:ponagnielnie ponaglenie None
# INFO:root:ponaglienie ponaglenie ponaglenie
# INFO:root:panagennie ponaglenie pangenie
# INFO:root:ponagleinie ponaglenie ponaglenie
# INFO:root:ponagenie ponaglenie ponaglenie
# INFO:root:ponagleniae ponaglenie ponaglenie
# INFO:root:ponagelenia ponaglenie ponaglenia
# INFO:root:ponagienie ponaglenie ponaglenie
# INFO:root:mezzczuzna mężczyzna None
# INFO:root:meężczysna mężczyzna mężczyzna
# INFO:root:męzszczyzan mężczyzna None
# INFO:root:męzczyzna mężczyzna mężczyzna
# INFO:root:mezczysnz mężczyzna meczysz
# INFO:root:mezczyna mężczyzna matczyna
# INFO:root:męczyzna mężczyzna mężczyzna
# INFO:root:meczyzna mężczyzna mężczyzna
# INFO:root:mężczyczna mężczyzna mężczyzna
# INFO:root:meęzczynsa mężczyzna None
# INFO:root:podranaiany podrabiany poradniany
# INFO:root:podtabiany podrabiany podrabiany
# INFO:root:podrabianzy podrabiany podrabiany
# INFO:root:podranbainy podrabiany podrabiany
# INFO:root:stanizwisko stanowisko staniewicko
# INFO:root:staniwosko stanowisko stanowisko
# INFO:root:stanownusko stanowisko stanowisko
# INFO:root:stanowisko stanowisko stanowisko
# INFO:root:stanowiskso stanowisko stanowisko
# INFO:root:snoatnowisko stanowisko None
# INFO:root:drukarnia drukarnia drukarnia
# INFO:root:drunkarani drukarnia drukarni
# INFO:root:drukarnia drukarnia drukarnia
# INFO:root:durarnia drukarnia drukarnia
# INFO:root:drunaikrnia drukarnia None
# INFO:root:druakanrnia drukarnia drukarnia
# INFO:root:druakarnai drukarnia drukarni
# INFO:root:teleofoniczna telefoniczna telefoniczna
# INFO:root:teleofinuczna telefoniczna telefoniczna
# INFO:root:telefoniaczan telefoniczna None
# INFO:root:telefoniaczna telefoniczna telefoniczna
# INFO:root:posóewiecenie poświęcenie None
# INFO:root:poswiecenie poświęcenie poświecenie
# INFO:root:poświecęnie poświęcenie poświecenie
# INFO:root:poświęceine poświęcenie poświęcenie
# INFO:root:posiwecenei poświęcenie None
# INFO:root:poswieceinie poświęcenie poświecenie
# INFO:root:mazliwnina małżowina None
# INFO:root:maąłżówinai małżowina None
# INFO:root:małążówina małżowina małżowina
# INFO:root:małźówina małżowina miłowana
# INFO:root:małówina małżowina małżowina
# INFO:root:małzowika małżowina miksowała
# INFO:root:małżoniwna małżowina małżowina
# INFO:root:wsrenrny wstrętny None
# INFO:root:wstrętnsy wstrętny wstrętny
# INFO:root:stretny wstrętny stratny
# INFO:root:wstrętnyy wstrętny wstrętny
# INFO:root:wstreutny wstrętny wstrętny
# INFO:root:ełripejeskich europejskich None
# INFO:root:euroeejskich europejskich europejskich
# INFO:root:europejskih europejskich europejskich
# INFO:root:europweojskich europejskich europejskich
# INFO:root:europejcksijch europejskich None
# INFO:root:eruoejskich europejskich europejskich
# INFO:root:kukułak kukułka kukułek
# INFO:root:kukulka kukułka kukułka
# INFO:root:kukilka kukułka kokilka
# INFO:root:kkulkaa kukułka kulaka
# INFO:root:kikiląka kukułka kokilka
# INFO:root:kukulka kukułka kukułka
# INFO:root:postawnowienie postawowienie postanowienie
# INFO:root:postawnienie postawowienie postawienie
# INFO:root:posttaąnowienie postawowienie postanowienie
# INFO:root:postanowieuenie postawowienie postanowienie
# INFO:root:postanowienie postawowienie postanowienie
# INFO:root:postaniwienie postawowienie postanowienie
# INFO:root:postastanwienei postawowienie None
# INFO:root:psoznienie spóźnienie pysznienie
# INFO:root:spóśńneinie spóźnienie None
# INFO:root:spozneinei spóźnienie None
# INFO:root:spoznienie spóźnienie spocznienie
# INFO:root:posóżnienie spóźnienie poróżnienie
# INFO:root:spoozneinei spóźnienie None
# INFO:root:spóźńienie spóźnienie spóźnienie
# INFO:root:spóźnieniee spóźnienie spóźnienie
# INFO:root:psoznienie spóźnienie pysznienie
# INFO:root:spóęznienie spóźnienie spocznienie
# INFO:root:ktory który kory
# INFO:root:ktury który kury
# INFO:root:któryy który który
# INFO:root:kttóry który który
# INFO:root:bezpblednie bezbłędnie bezbłędnie
# INFO:root:bezblednie bezbłędnie bezbłędnie
# INFO:root:beżbłęenie bezbłędnie bezbłędnie
# INFO:root:bezpblednie bezbłędnie bezbłędnie
# INFO:root:bezbłędnie bezbłędnie bezbłędne
# INFO:root:bezbłędniee bezbłędnie bezbłędnie
# INFO:root:przenczytawszy przeczytawszy przeczytawszy
# INFO:root:przeczyrtawsnzy przeczytawszy przeczytawszy
# INFO:root:przeczyrtawszy przeczytawszy przeczytawszy
# INFO:root:przeczytawnuyszy przeczytawszy None
# INFO:root:przeczytawszy przeczytawszy przeczytawszy
# INFO:root:preczyrtawszy przeczytawszy przeczytawszy
# INFO:root:peirania pirania pirania
# INFO:root:piraania pirania pirania
# INFO:root:piratnia pirania pirania
# INFO:root:priania pirania piania
# INFO:root:szcuzapak szczupak szczupak
# INFO:root:szcupaak szczupak szczupak
# INFO:root:szczupaak szczupak szczupak
# INFO:root:resteartuacja restauracja None
# INFO:root:restaustiacja restauracja None
# INFO:root:restatwuracja restauracja restauracja
# INFO:root:restuautacja restauracja restauracja
# INFO:root:restuaurajac restauracja restaurując
# INFO:root:rtestauracja restauracja restauracja
# INFO:root:reęstauracaja restauracja restauracja
# INFO:root:trerorysta terrorysta terrorysta
# INFO:root:rerrorystya terrorysta None
# INFO:root:terrorystya terrorysta terrorysta
# INFO:root:terrorystaa terrorysta terrorysta
# INFO:root:trsotysta terrorysta None
# INFO:root:rerorysta terrorysta rygorysta
# INFO:root:trorrwysta terrorysta terrorysta
# INFO:root:teroroysta terrorysta terrorysta
# INFO:root:rpzedszkole przedszkole None
# INFO:root:rpzedszkole przedszkole None
# INFO:root:pszedskole przedszkole przedszkole
# INFO:root:przedszkoele przedszkole przedszkole
# INFO:root:przedszsskoel przedszkole None
# INFO:root:prorgamownaienie programowanie None
# INFO:root:programoeniwanie programowanie None
# INFO:root:prorgramoewanie programowanie programowanie
# INFO:root:programowawie programowanie programowanie
# INFO:root:prrogramowaniee programowanie programowanie
# INFO:root:programowaienie programowanie programowanie
# INFO:root:programowanie programowanie programowane
# INFO:root:progamowanie programowanie programowanie
# INFO:root:prgraamowanie programowanie programowanie
# INFO:root:prorgamowanie programowanie programowanie
# INFO:root:programowoanie programowanie programowanie
# INFO:root:programowanrie programowanie programowanie
# INFO:root:prorgamowanawnie programowanie None
# INFO:root:przeuyślał przemyślał przemyślał
# INFO:root:przemuysłął przemyślał None
# INFO:root:przemysłął przemyślał przesyłał
# INFO:root:przemyśłął przemyślał przemyślał
# INFO:root:przemuslal przemyślał None
# INFO:root:przymyslal przemyślał None
# INFO:root:pudeleko pudełko pudełko
# INFO:root:pudełkoo pudełko pudełko
# INFO:root:pudelkol pudełko None
# INFO:root:pudkleko pudełko pudełko
# INFO:root:pudleko pudełko pudlego
# INFO:root:pudłeko pudełko pudełko
# INFO:root:telegrarm telegram telegram
# INFO:root:telegfam telegram telegram
# INFO:root:telrgramo telegram None
# INFO:root:teletgeam telegram telegram
# INFO:root:telegranm telegram telegram
# INFO:root:kalareppa kalarepa kalarepa
# INFO:root:kalapea kalarepa kalatea
# INFO:root:ogródeek ogródek ogródek
# INFO:root:ogreodek ogródek ogródek
# INFO:root:ogródękk ogródek ogródek
# INFO:root:orgudek ogródek ordunek
# INFO:root:komiunakacja komunikacja komunikacja
# INFO:root:koiunikacja komunikacja komunikacja
# INFO:root:kominiakaca komunikacja None
# INFO:root:komunijajca komunikacja komunikacja
# INFO:root:komuniakacja komunikacja komunikacja
# INFO:root:komuniakacjaa komunikacja komunikacja
# INFO:root:konuniakcaja komunikacja None
# INFO:root:slamarazanosc ślamazarność None
# INFO:root:śłąmararność ślamazarność ślamazarność
# INFO:root:slamaraenosc ślamazarność None
# INFO:root:slamazarosc ślamazarność None
# INFO:root:slamazarność ślamazarność None
# INFO:root:slamanzanosc ślamazarność None
# INFO:root:ślaamazarnoscóść ślamazarność None
# INFO:root:slamazarnoscć ślamazarność None
# INFO:root:łśąmazarność ślamazarność None
# INFO:root:slamazarnoscć ślamazarność None
# INFO:root:wyatkowrego wyjątkowego wydatkowego
# INFO:root:wyjatkowmego wyjątkowego wyjątkowego
# INFO:root:wujątkowmego wyjątkowego wyjątkowego
# INFO:root:wyjatkoweggo wyjątkowego wyjątkowego
# INFO:root:wyjaktnowego wyjątkowego wyjątkowego
# INFO:root:podpiszczac podpuszczać None
# INFO:root:pudpuszczac podpuszczać None
# INFO:root:podpszżczać podpuszczać podpuszczać
# INFO:root:posdupszcać podpuszczać None
# INFO:root:pudpudszczać podpuszczać podpuszczać
# INFO:root:podpuszczać podpuszczać popuszczać
# 0.5289256198347108
